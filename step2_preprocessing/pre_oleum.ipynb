# %%
import folium
import requests
import pandas as pd 
from urllib.parse import quote

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/workspace/project1/제주오름.csv", encoding='utf-8')
df
# Out:
#       오름명            주소  비고(m)  표고(m)          경도         위도  Unnamed: 6  \
# 0    아부오름   제주시 구좌읍 송당리     51  301.4  126.777283  33.448875         NaN
# 1   아끈다랑쉬   제주시 구좌읍 세화리     58  198.0  126.830652  33.474137         NaN
# 2    알밤오름   제주시 조천읍 선흘리    154  393.6  126.885675  33.480757         NaN
# 3     알오름  서귀포시 성산읍 시흥리     51  145.9  126.713135  33.489746         NaN
# 4    안돌오름   제주시 구좌읍 송당리     93  368.1  126.757126  33.455814         NaN
# ..    ...           ...    ...    ...         ...        ...         ...
# 85  열안지오름       제주시 봉개동     54  328.0  126.605356  33.473074         NaN
# 86    영천악      서귀포시 상효동     97  277.0  126.600677  33.295338         NaN
# 87    영주산  서귀포시 표선면 성읍리    176  326.4  126.796245  33.404568         NaN
# 88  용눈이오름   제주시 구좌읍 종달리     88  247.8  126.832690  33.459878         NaN
# 89  유건에오름  서귀포시 성산읍 난산리     75  190.2  126.847069  33.413563         NaN
#
#     Unnamed: 7
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# ...

# %%
df.drop('Unnamed: 7', axis=1, inplace=True)

# %%
df
# Out:
#       오름명            주소  비고(m)  표고(m)          경도         위도
# 0    아부오름   제주시 구좌읍 송당리     51  301.4  126.777283  33.448875
# 1   아끈다랑쉬   제주시 구좌읍 세화리     58  198.0  126.830652  33.474137
# 2    알밤오름   제주시 조천읍 선흘리    154  393.6  126.885675  33.480757
# 3     알오름  서귀포시 성산읍 시흥리     51  145.9  126.713135  33.489746
# 4    안돌오름   제주시 구좌읍 송당리     93  368.1  126.757126  33.455814
# ..    ...           ...    ...    ...         ...        ...
# 85  열안지오름       제주시 봉개동     54  328.0  126.605356  33.473074
# 86    영천악      서귀포시 상효동     97  277.0  126.600677  33.295338
# 87    영주산  서귀포시 표선면 성읍리    176  326.4  126.796245  33.404568
# 88  용눈이오름   제주시 구좌읍 종달리     88  247.8  126.832690  33.459878
# 89  유건에오름  서귀포시 성산읍 난산리     75  190.2  126.847069  33.413563
#
# [90 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# 오름명      0
# 주소       0
# 비고(m)    0
# 표고(m)    0
# 경도       0
# 위도       0
# dtype: int64

# %%
df.dtypes
# Out:
# 오름명       object
# 주소        object
# 비고(m)      int64
# 표고(m)    float64
# 경도       float64
# 위도       float64
# dtype: object

# %%
df.head(5)
# Out:
#      오름명            주소  비고(m)  표고(m)          경도         위도
# 0   아부오름   제주시 구좌읍 송당리     51  301.4  126.777283  33.448875
# 1  아끈다랑쉬   제주시 구좌읍 세화리     58  198.0  126.830652  33.474137
# 2   알밤오름   제주시 조천읍 선흘리    154  393.6  126.885675  33.480757
# 3    알오름  서귀포시 성산읍 시흥리     51  145.9  126.713135  33.489746
# 4   안돌오름   제주시 구좌읍 송당리     93  368.1  126.757126  33.455814

# %%
df['오름명'].unique()
# Out:
# array(['아부오름', '아끈다랑쉬', '알밤오름', '알오름', '안돌오름', '안세미', '백약이오름', '밝은오름',
#        '바농오름', '비치미오름', '밧돌오름', '천아오름', '칡오름', '대병악', '대수산봉', '대왕산',
#        '다랑쉬', '달산봉', '당오름', '당산봉', '단산', '도청오름', '독자봉', '돔배오름', '돛오름',
#        '둔지봉', '두산봉', '어대오름', '어도오름', '은월봉(윤드리오름)', '갑선이오름', '개오름(성읍)',
#        '가마오름', '감낭오름', '가세오름', '가시오름', '거린오름', '걸리오름', '거문오름', '거슨세미',
#        '갯거리오름', '극락오름', '금오름', '고근산', '궁대악', '군산', '이달봉', '이달이촛대봉',
#        '인정오름', '자배봉', '제지기오름', '저지오름', '정물오름', '제석오름', '지미봉', '좌보미',
#        '모구리오름', '모지오름', '무악(개오름)', '명월오름', '묘산봉', '남산봉', '낭끼오름', '넉시악',
#        '늡서리', '높은오름', '삼매봉', '생길이오름', '서걸세', '설오름', '성불오름', '섯알오름', '서우봉',
#        '새신오름', '식은이오름', '식산봉', '소병악', '송악산', '수산봉(물메)', '통오름', '토산봉',
#        '따라비오름', '우진제비', '월랑지', '원물오름', '열안지오름', '영천악', '영주산', '용눈이오름',
#        '유건에오름'], dtype=object)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
import requests, json
import pandas as pd
from urllib.parse import quote

# %%
with open('/workspace/project1/KakaoAPI.txt.txt') as file:
    road_key = file.read()

# %%
base_url = 'https://dapi.kakao.com/v2/local/search/address.json'
addr = '제주 제주시 한림읍 금악리 산1-1'
url = f'{base_url}?query={quote(addr)}'

# %%
header = {'Authorization': f'KakaoAK {road_key}'}

# %%
result = requests.get(url, headers=header).json()
result
# Out:
# {'documents': [{'address': {'address_name': '제주특별자치도 제주시 한림읍 금악리 산 1-1',
#     'b_code': '5011025025',
#     'h_code': '5011025000',
#     'main_address_no': '1',
#     'mountain_yn': 'Y',
#     'region_1depth_name': '제주특별자치도',
#     'region_2depth_name': '제주시',
#     'region_3depth_h_name': '한림읍',
#     'region_3depth_name': '한림읍 금악리',
#     'sub_address_no': '1',
#     'x': '126.305586388283',
#     'y': '33.3556958434344'},
#    'address_name': '제주특별자치도 제주시 한림읍 금악리 산 1-1',
#    'address_type': 'REGION_ADDR',
#    'road_address': None,
#    'x': '126.305586388283',
#    'y': '33.3556958434344'}],
#  'meta': {'is_end': True, 'pageable_count': 1, 'total_count': 1}}

# %%
import folium
import pandas as pd

# %%
map = folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=14)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map = folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=14)
for i in df.index:
    folium.Marker(
        location=[df.위도[i], df.경도[i]],
        tooltip=df.오름명[i],
        popup = folium.Popup(df.주소[i], max_width=200) 
    ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
