# %%
import folium
import requests
import pandas as pd 
from urllib.parse import quote

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/workspace/project1/올레코스현황.csv", encoding='cp949')
df
# Out:
#        코스별                   코스명  거리(km) 소요시간정보         코스시점         코스종점  \
# 0      1코스              시흥 - 광치기    15.1  4.5시간       시흥리정류장       광치기 해변
# 1      2코스              광치기 - 온평    15.6  4.5시간        광치기해변         온평포구
# 2      3코스            온평 - 표선(A)    20.9  6.5시간         온평포구       표선해수욕장
# 3      3코스            온평 - 표선(B)    14.6  4.5시간         온평포구       표선해수욕장
# 4      4코스               표선 - 남원    19.0  6.5시간       표선해수욕장         남원포구
# 5      5코스              남원 - 쇠소깍    13.4  4.5시간         남원포구        쇠소깍다리
# 6      6코스       쇠소깍 - 제주올레여행자센터    11.0  3.5시간        쇠소깍다리    제주올레여행자센터
# 7      7코스        제주올레여행자센터 - 월평    17.6  5.5시간    제주올레여행자센터    월평 아왜낭목쉼터
# 8      8코스               월평 - 대평    19.6  5.5시간      월평 아왜낭목         대평포구
# 9      9코스               대평 - 화순    11.8  3.5시간         대평포구   화순 금모래해수욕장
# 10    10코스              화순 - 모슬포    15.6  5.5시간    제주올레공식안내소       하모체육공원
# 11    11코스              모슬포 - 무릉    17.3  5.5시간       하모체육공원        무릉외갓집
# ...

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import requests, json
import pandas as pd
from urllib.parse import quote
import folium
import pandas as pd

# %%
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
map = folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=14)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map = folium.Map(location=[df.위도.mean(), df.경도.mean()], zoom_start=10)
for i in df.index:
    folium.Marker(
        location=[df.위도[i], df.경도[i]],
        tooltip=df.코스시점[i],
        popup = folium.Popup(df.코스시점주소[i], max_width=200) 
    ).add_to(map)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
